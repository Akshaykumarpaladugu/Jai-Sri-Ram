# %%
#printing Jai Sri Ram 100 times using Range

a=int(input("enter your number:"))

for i in range(a):
    print("Jai Sri Ram \n "*i) # \n is used because to print in new line
# Out:
# enter your number:100
#
# Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#
# Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
#  Jai Sri Ram
# ...
